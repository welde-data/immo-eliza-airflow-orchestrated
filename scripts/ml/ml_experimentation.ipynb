# %% [markdown]
# ## Imports and Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# 1. Setup path (relative to the /tests folder)
DATA_PATH = os.path.join("..", "data", "processed", "properties_ml_ready.csv")

# 2. Load the data
try:
    df = pd.read_csv(DATA_PATH)
    print(f"✅ Loaded {len(df)} properties successfully.")
except Exception as e:
    print(f"❌ Error loading data: {e}")

# 3. Quick overview
display(df.head())
display(df.info())
